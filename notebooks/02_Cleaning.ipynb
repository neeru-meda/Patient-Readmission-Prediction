# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv('d:\\Codes\\Patient_Readmission_Prediction\\data\\raw\\diabetic_data.csv')

# %%
df = df.replace('?', np.nan)
df_missing_values_columns = df.columns[df.isnull().any()]
print("Columns with missing values:")
print(df_missing_values_columns.tolist())
print("\nMissing values count for each column:")
total_missing = df[df_missing_values_columns].isnull().sum()
print(total_missing)
print("\nPercentage of missing values for each column:")
missing_percentage = (total_missing / len(df)) * 100
print(missing_percentage)
# Out:
# Columns with missing values:
# ['race', 'weight', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult']
#
# Missing values count for each column:
# race                  2273
# weight               98569
# payer_code           40256
# medical_specialty    49949
# diag_1                  21
# diag_2                 358
# diag_3                1423
# max_glu_serum        96420
# A1Cresult            84748
# dtype: int64
#
# Percentage of missing values for each column:
# race                  2.233555
# weight               96.858479
# payer_code           39.557416
# medical_specialty    49.082208
# diag_1                0.020636
# diag_2                0.351787
# diag_3                1.398306
# max_glu_serum        94.746772
# A1Cresult            83.277322
# dtype: float64

# %% [markdown]
# The columns that have the missing value percentage more than 40% are weight with 97% and payer_code with 40% , medical_specialty with 49% , max_glu_serum with 95% and A1Cresult with 83%

# %%
cols_to_drop = ['weight', 'payer_code', 'medical_specialty','encounter_id']
df = df.drop(columns=cols_to_drop)
print("Columns after dropping:")
print(df.columns.tolist())
# Out:
# Columns after dropping:
# ['patient_nbr', 'race', 'gender', 'age', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']

# %%
df['target'] = (df['readmitted']== '<30').astype(int)
df['target'].value_counts()
df = df.drop(columns=['readmitted'])

# %%
# Keep only the most recent encounter per patient
df = df.drop_duplicates(subset='patient_nbr', keep='last')

# %%
#Each age range is replaced by its midpoint.
age_map = {
    '[0-10)': 5,
    '[10-20)': 15,
    '[20-30)': 25,
    '[30-40)': 35,
    '[40-50)': 45,
    '[50-60)': 55,
    '[60-70)': 65,
    '[70-80)': 75,
    '[80-90)': 85,
    '[90-100)': 95
} 
df['age_numeric']= df['age'].map(age_map)
df = df.drop(columns=['age'])

# %%
df.to_csv('d:\\Codes\\Patient_Readmission_Prediction\\data\\processed\\diabetic_data_cleaned.csv', index=False)
print("Cleaned data saved!")
# Out:
# Cleaned data saved!
